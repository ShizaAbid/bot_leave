# %%
import pandas as pd
import numpy as np
from nltk import ngrams

# %%
train= pd.read_excel("C:\\Users\\shiza.abid\\Desktop\\DataSetLeave_FinalMerge.xlsx")
train.shape
# Out:
# (262, 3)

# %%
train.head(10)
# Out:
#    Number                                               Text         Class
# 0       1               I am willing to take leave for today  LeaveRequest
# 1       2                   I need a sick leave for tomorrow  LeaveRequest
# 2       3                      Please show my pending leaves  LeaveEnquiry
# 3       4        I will take leave from 4th march to 8th dec  LeaveRequest
# 4       5         I will not join office from 6th to 9th dec  LeaveRequest
# 5       6                        I am going on annual leaves  LeaveRequest
# 6       7            I will go to casual leave for 5th march  LeaveRequest
# 7       8      Can you please apply a leave on behave of me.  LeaveRequest
# 8       9  Can you please request for a sick leave for 8t...  LeaveRequest
# 9      10            Can you please grant me a casual leave.  LeaveRequest

# %%
train.loc[train.Class == 'LeaveRequest']
# Out:
#      Number                                               Text         Class
# 0         1               I am willing to take leave for today  LeaveRequest
# 1         2                   I need a sick leave for tomorrow  LeaveRequest
# 3         4        I will take leave from 4th march to 8th dec  LeaveRequest
# 4         5         I will not join office from 6th to 9th dec  LeaveRequest
# 5         6                        I am going on annual leaves  LeaveRequest
# 6         7            I will go to casual leave for 5th march  LeaveRequest
# 7         8      Can you please apply a leave on behave of me.  LeaveRequest
# 8         9  Can you please request for a sick leave for 8t...  LeaveRequest
# 9        10            Can you please grant me a casual leave.  LeaveRequest
# 17       18                        I am going to off tommorrow  LeaveRequest
# 18       19                           I need a break for today  LeaveRequest
# 19       20                               I need to go at 3pm   LeaveRequest
# 20       21                             I will go at 5pm today  LeaveRequest
# 21       22                           i will go on short break  LeaveRequest
# 22       23                    I am willing to take leave for   LeaveRequest
# 23       24            I am willing to take leave for tomorrow  LeaveRequest
# 24       25                      I need a sick leave for today  LeaveRequest
# 25       26                            I need a sick leave for  LeaveRequest
# 29       30  I am planning to take annual leaves from 25th ...  LeaveRequest
# 30       31           I have to go to my son’s school tomorrow  LeaveRequest
# 33       34                     Apply a casual leave for today  LeaveRequest
# 34       35                       Apply a sick leave for today  LeaveRequest
# 35       36                       Apply Annual leave for today  LeaveRequest
# 36       37                       Apply Earned leave for today  LeaveRequest
# 37       38                Apply Earned/Annual leave for today  LeaveRequest
# 39       40                              I am not feeling well  LeaveRequest
# 40       41  I am not feeling well. can you please apply fo...  LeaveRequest
# 41       42                                    I am sick today  LeaveRequest
# 42       43                   I don’t feel like going to work.  LeaveRequest
# 43       44                    I don’t think I can go to work.  LeaveRequest
# ..      ...                                                ...           ...
# 209     210            I am going to JAMAT for selected dates.  LeaveRequest
# 210     211  I coudn't join Office today due to some Family...  LeaveRequest
# 211     212  I will not able to come tommorrow due to my mo...  LeaveRequest
# 212     213  I will not join office because I have to take ...  LeaveRequest
# 213     214    I coudn't join office tommorrow due to my paper  LeaveRequest
# 214     215                     I wont be joining office today  LeaveRequest
# 215     216                           I am sick today/tommorow  LeaveRequest
# 219     220  please apply annual leaves from 25th feb to 1s...  LeaveRequest
# 220     221                       I am going somewhere tomorow  LeaveRequest
# 223     224             I want to apply casual leave for today  LeaveRequest
# 224     225                               I am very sick today  LeaveRequest
# 225     226                please apply annual leave for today  LeaveRequest
# 226     227                please apply earned leave for today  LeaveRequest
# 228     229                              I am very tired today  LeaveRequest
# 229     230                     I wont be joining office today  LeaveRequest
# 232     233               I am planning a trip in my vacations  LeaveRequest
# 234     235                     I need to take some rest today  LeaveRequest
# 235     236                        I am not going office today  LeaveRequest
# 236     237                        I am not feeling well today  LeaveRequest
# 239     240       apply annual leaves from 25th feb to 1st dec  LeaveRequest
# 240     241                     I have to go somewhere tomorow  LeaveRequest
# 244     245                            I don’t feel good today  LeaveRequest
# 250     251                         I want to take leave today  LeaveRequest
# 251     252                     I don’t think I am well  today  LeaveRequest
# 255     256                       I will be taking leave today  LeaveRequest
# 256     257                               I am very sick today  LeaveRequest
# 257     258                I am not willing to go office today  LeaveRequest
# 258     259                              Lets take leave today  LeaveRequest
# 259     260                     I need to take some rest today  LeaveRequest
# 261     262  I am writing to document my absence due to ill...  LeaveRequest
#
# [190 rows x 3 columns]

# %%
train.loc[train.Class == 'LeaveEnquiry']
# Out:
#      Number                                               Text         Class
# 2         3                      Please show my pending leaves  LeaveEnquiry
# 10       11                         Please show my all leaves.  LeaveEnquiry
# 11       12         Please tell me the balance of casual leave  LeaveEnquiry
# 12       13           Please tell me the balance of sick leave  LeaveEnquiry
# 13       14         Please tell me the balance of annual leave  LeaveEnquiry
# 14       15               Please initiate me my leave balances  LeaveEnquiry
# 15       16       Please provide me the list of leave balances  LeaveEnquiry
# 16       17                Please prompt me the leave balances  LeaveEnquiry
# 26       27                              Please show my leaves  LeaveEnquiry
# 27       28         When will I get my annual leaves refreshed  LeaveEnquiry
# 28       29                  Do I have any sick leave balance?  LeaveEnquiry
# 31       32           When will my casual leave balance expire  LeaveEnquiry
# 32       33                 Who is my leave approval authority  LeaveEnquiry
# 38       39                              Current leave balance  LeaveEnquiry
# 51       52                           Remaining leave balance?  LeaveEnquiry
# 52       53               Show me the remaining leave balances  LeaveEnquiry
# 53       54               Show the remainig sick leave balance  LeaveEnquiry
# 54       55            Show the remaining annual leave balance  LeaveEnquiry
# 55       56            Show the remaining casual leave balance  LeaveEnquiry
# 56       57            Show the remaining earned leave balance  LeaveEnquiry
# 57       58     Show the remaining earned/annual leave balance  LeaveEnquiry
# 58       59                          Tell me my leave balances  LeaveEnquiry
# 59       60                         What are my leave balances  LeaveEnquiry
# 60       61                    What is my annual leave balance  LeaveEnquiry
# 61       62                    What is my casual leave balance  LeaveEnquiry
# 62       63                    What is my earned leave balance  LeaveEnquiry
# 63       64             What is my earned/annual leave balance  LeaveEnquiry
# 64       65                           What is my leave balance  LeaveEnquiry
# 65       66                      What is my sick leave balance  LeaveEnquiry
# 66       67                  What is the current leave balance  LeaveEnquiry
# ..      ...                                                ...           ...
# 147     148       How many leaves are remaining for this month  LeaveEnquiry
# 148     149             How many leaves I can avail in a month  LeaveEnquiry
# 149     150      What is the Procedure to get a leave approved  LeaveEnquiry
# 175     176       It is requested to confirm my leaves balance  LeaveEnquiry
# 186     187    I would like to see my remaining pending leaves  LeaveEnquiry
# 187     188  I would like to inquire about, when will my an...  LeaveEnquiry
# 189     190           How many sick leaves can be taken by me?  LeaveEnquiry
# 216     217               please let me know my pending leaves  LeaveEnquiry
# 217     218                     when annual leaves are refresh  LeaveEnquiry
# 218     219                      are there any sick leave left  LeaveEnquiry
# 221     222                what is my casual leave expiry date  LeaveEnquiry
# 222     223         I want to know my leave approval authority  LeaveEnquiry
# 227     228                   what is my current leave balance  LeaveEnquiry
# 230     231                    what is my  leave collapse date  LeaveEnquiry
# 231     232                       when can I get my new leaves  LeaveEnquiry
# 233     234             how many of my casual leaves be in feb  LeaveEnquiry
# 237     238                   I want to know my pending leaves  LeaveEnquiry
# 238     239                    do I have remaining sick leaves  LeaveEnquiry
# 241     242               what is my casual leave renewal date  LeaveEnquiry
# 242     243            let me know my leave approval authority  LeaveEnquiry
# 243     244                 I will not be joining office today  LeaveEnquiry
# 245     246                     how many pending leaves I have  LeaveEnquiry
# 246     247  what is my date of annual leave refresh/refres...  LeaveEnquiry
# 247     248                      what is my sick leave balance  LeaveEnquiry
# 248     249  I want to go to annual leaves from 25th novemb...  LeaveEnquiry
# 249     250                         who authorize to my leaves  LeaveEnquiry
# 252     253                          who is my leave authority  LeaveEnquiry
# 253     254      who is my direct reporting with repect  leave  LeaveEnquiry
# 254     255                       any sick leave balance left   LeaveEnquiry
# 260     261                    what is leave incashment policy  LeaveEnquiry
#
# [71 rows x 3 columns]

# %%
print('Average count of phrases per sentence in train is {0:.0f}.'.format(train.groupby('Class')['Text'].count().mean()))
#print('Average count of phrases per sentence in test is {0:.0f}.'.format(test.groupby('Class')['Text'].count().mean()))
train.groupby('Class')['Text'].count().mean()
# Out:
# Average count of phrases per sentence in train is 87.
# 87.33333333333333

# %%
print('Number of phrases in train: {}. Number of sentences in train: {}.'.format(train.shape[0], len(train.Text.unique())))
# Out:
# Number of phrases in train: 262. Number of sentences in train: 256.

# %%
print('Average word length of phrases in train is {0:.0f}.'.format(np.mean(train['Text'].apply(lambda x: len(x.split())))))
# Out:
# Average word length of phrases in train is 8.

# %%
text_leave = ' '.join(train.loc[train.Class == 'LeaveRequest', 'Text'].values)
text_trigrams_l = [i for i in ngrams(text_leave.split(), 4)]
text_i = ' '.join(train.loc[train.Class == 'LeaveEnquiry', 'Text'].values)
text_trigrams_i = [i for i in ngrams(text_i.split(), 4)]

# %%
import collections
l=collections.Counter(text_trigrams_l).most_common(30)
l_list=[]
for a in range(30):
    l_list.append(l[a][0])

# %%
i=collections.Counter(text_trigrams_i).most_common(30)
i_list=[]
for a in range(30):
    i_list.append(i[a][0])
i_list
# Out:
# [('leave', 'balance', 'What', 'is'),
#  ('balance', 'What', 'is', 'my'),
#  ('leave', 'balance', 'Show', 'the'),
#  ('balance', 'Show', 'the', 'remaining'),
#  ('Please', 'tell', 'me', 'the'),
#  ('tell', 'me', 'the', 'balance'),
#  ('me', 'the', 'balance', 'of'),
#  ('my', 'leave', 'approval', 'authority'),
#  ('is', 'my', 'casual', 'leave'),
#  ('leave', 'Please', 'tell', 'me'),
#  ('me', 'my', 'leave', 'balances'),
#  ('my', 'casual', 'leave', 'balance'),
#  ('my', 'leave', 'balances', 'What'),
#  ('is', 'my', 'sick', 'leave'),
#  ('my', 'sick', 'leave', 'balance'),
#  ('Am', 'I', 'eligible', 'to'),
#  ('annual', 'leave', 'this', 'year?'),
#  ('year?', 'When', 'will', 'my'),
#  ('I', 'get', 'my', 'new'),
#  ('I', 'would', 'like', 'to'),
#  ('let', 'me', 'know', 'my'),
#  ('know', 'my', 'pending', 'leaves'),
#  ('what', 'is', 'my', 'casual'),
#  ('I', 'want', 'to', 'know'),
#  ('want', 'to', 'know', 'my'),
#  ('know', 'my', 'leave', 'approval'),
#  ('Please', 'show', 'my', 'pending'),
#  ('show', 'my', 'pending', 'leaves'),
#  ('my', 'pending', 'leaves', 'Please'),
#  ('pending', 'leaves', 'Please', 'show')]

# %%
train.Class
# Out:
# 0      LeaveRequest
# 1      LeaveRequest
# 2      LeaveEnquiry
# 3      LeaveRequest
# 4      LeaveRequest
# 5      LeaveRequest
# 6      LeaveRequest
# 7      LeaveRequest
# 8      LeaveRequest
# 9      LeaveRequest
# 10     LeaveEnquiry
# 11     LeaveEnquiry
# 12     LeaveEnquiry
# 13     LeaveEnquiry
# 14     LeaveEnquiry
# 15     LeaveEnquiry
# 16     LeaveEnquiry
# 17     LeaveRequest
# 18     LeaveRequest
# 19     LeaveRequest
# 20     LeaveRequest
# 21     LeaveRequest
# 22     LeaveRequest
# 23     LeaveRequest
# 24     LeaveRequest
# 25     LeaveRequest
# 26     LeaveEnquiry
# 27     LeaveEnquiry
# 28     LeaveEnquiry
# 29     LeaveRequest
#            ...
# 232    LeaveRequest
# 233    LeaveEnquiry
# 234    LeaveRequest
# 235    LeaveRequest
# 236    LeaveRequest
# 237    LeaveEnquiry
# 238    LeaveEnquiry
# 239    LeaveRequest
# 240    LeaveRequest
# 241    LeaveEnquiry
# 242    LeaveEnquiry
# 243    LeaveEnquiry
# 244    LeaveRequest
# 245    LeaveEnquiry
# 246    LeaveEnquiry
# 247    LeaveEnquiry
# 248    LeaveEnquiry
# 249    LeaveEnquiry
# 250    LeaveRequest
# 251    LeaveRequest
# 252    LeaveEnquiry
# 253    LeaveEnquiry
# 254    LeaveEnquiry
# 255    LeaveRequest
# 256    LeaveRequest
# 257    LeaveRequest
# 258    LeaveRequest
# 259    LeaveRequest
# 260    LeaveEnquiry
# 261    LeaveRequest
# Name: Class, Length: 262, dtype: object

# %%
collect_top=[]
collect_top.append(l_list)
collect_top.append(i_list)

# %%
print("Cluster 1 words:",collect_top[0])
print("Cluster 2 words:",collect_top[1])
# Out:
# Cluster 1 words: [('I', 'need', 'a', 'leave'), ('a', 'sick', 'leave', 'for'), ('leave', 'for', 'today', 'I'), ('I', 'was', 'unable', 'to'), ('unable', 'to', 'attend', 'work'), ('I', 'would', 'like', 'to'), ('today', 'I', 'am', 'not'), ('need', 'a', 'leave', 'to'), ('a', 'leave', 'to', 'attend'), ('leave', 'to', 'attend', 'a'), ('I', 'am', 'willing', 'to'), ('annual', 'leaves', 'from', '25th'), ('leave', 'for', 'today', 'Apply'), ('am', 'not', 'feeling', 'well'), ('to', 'go', 'to', 'office'), ('office', 'today', 'I', 'am'), ('was', 'unable', 'to', 'attend'), ('I', 'am', 'writing', 'to'), ('to', 'attend', 'work', 'on'), ('would', 'like', 'to', 'request'), ('leave', 'for', 'me', 'apply'), ('for', 'me', 'apply', 'a'), ('am', 'willing', 'to', 'take'), ('willing', 'to', 'take', 'leave'), ('to', 'take', 'leave', 'for'), ('for', 'today', 'I', 'need'), ('today', 'I', 'need', 'a'), ('I', 'need', 'a', 'sick'), ('need', 'a', 'sick', 'leave'), ('I', 'will', 'not', 'join')]
# Cluster 2 words: [('leave', 'balance', 'What', 'is'), ('balance', 'What', 'is', 'my'), ('leave', 'balance', 'Show', 'the'), ('balance', 'Show', 'the', 'remaining'), ('Please', 'tell', 'me', 'the'), ('tell', 'me', 'the', 'balance'), ('me', 'the', 'balance', 'of'), ('my', 'leave', 'approval', 'authority'), ('is', 'my', 'casual', 'leave'), ('leave', 'Please', 'tell', 'me'), ('me', 'my', 'leave', 'balances'), ('my', 'casual', 'leave', 'balance'), ('my', 'leave', 'balances', 'What'), ('is', 'my', 'sick', 'leave'), ('my', 'sick', 'leave', 'balance'), ('Am', 'I', 'eligible', 'to'), ('annual', 'leave', 'this', 'year?'), ('year?', 'When', 'will', 'my'), ('I', 'get', 'my', 'new'), ('I', 'would', 'like', 'to'), ('let', 'me', 'know', 'my'), ('know', 'my', 'pending', 'leaves'), ('what', 'is', 'my', 'casual'), ('I', 'want', 'to', 'know'), ('want', 'to', 'know', 'my'), ('know', 'my', 'leave', 'approval'), ('Please', 'show', 'my', 'pending'), ('show', 'my', 'pending', 'leaves'), ('my', 'pending', 'leaves', 'Please'), ('pending', 'leaves', 'Please', 'show')]

# %%
import pandas as pd
import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

final= pd.read_excel("C:\\Users\\shiza.abid\\Desktop\\DataSetLeave_FinalMerge.xlsx")
docsc=final['Class']
docst=final['Text']
final.shape

from nltk.stem.snowball import SnowballStemmer
stemmer= SnowballStemmer("english")
stopwords = nltk.corpus.stopwords.words('english')
stopwords.append("i")

def token_stems(text):
        
    tokens=tokenizing(text) 
    #print(tokens)
    stems=stemming(tokens)
    return stems       

def tokenizing(text):
    
    #breaking each word and making them tokens
    tokens=[word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    
    #storing only alpha tokens
    filtered_tokens=[]
    for token in tokens:
        if (re.search('[a-zA-Z]', token)):
            filtered_tokens.append(token)

    return filtered_tokens
    
def stemming(text):
    
    stems =[stemmer.stem(t) for t in text]
    return stems

tfidfs= TfidfVectorizer(min_df=0.05, stop_words=stopwords, tokenizer=token_stems,
                      use_idf=True)

tfidfs_matriz= tfidfs.fit_transform(docst)

print(tfidfs_matriz.shape)

dists = 1 - cosine_similarity(tfidfs_matriz)

terms=tfidfs.get_feature_names()
# Out:
# (262, 18)
# C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'s", 'abov', 'ani', 'becaus', 'befor', 'could', 'doe', 'dure', 'might', 'must', "n't", 'need', 'onc', 'onli', 'ourselv', 'sha', 'themselv', 'veri', 'whi', 'wo', 'would', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
f_list=[]
for data in range(len(docst)):
   f_list.append(tokenizing(docst[data]))

import itertools
#print(docst[a])
merged = list(itertools.chain.from_iterable(docst))
#merged

feature_list=[]
for a in range(len(docst)):
    #print(docst[a])
    word = tokenizing(docst[a])
    #print(word)
    rows=[]
    for b in range(len(terms)):
        if terms[b] in word:
            rows.append(1)
        else:
            rows.append(0)
feature_list.append(rows)


newDF=pd.DataFrame(feature_list,index = docst,columns = terms)
newDF.shape
# Out:
# (262, 18)

# %%
newDF
# Out:
#                                                     annual  appli  attend  \
# Text
# I am willing to take leave for today                     0      0       0
# I need a sick leave for tomorrow                         0      0       0
# Please show my pending leaves                            0      0       0
# I will take leave from 4th march to 8th dec              0      0       0
# I will not join office from 6th to 9th dec               0      0       0
# I am going on annual leaves                              0      0       0
# I will go to casual leave for 5th march                  0      0       0
# Can you please apply a leave on behave of me.            0      0       0
# Can you please request for a sick leave for 8th...       0      0       0
# Can you please grant me a casual leave.                  0      0       0
# Please show my all leaves.                               0      0       0
# Please tell me the balance of casual leave               0      0       0
# Please tell me the balance of sick leave                 0      0       0
# Please tell me the balance of annual leave               0      0       0
# Please initiate me my leave balances                     0      0       0
# Please provide me the list of leave balances             0      0       0
# Please prompt me the leave balances                      0      0       0
# I am going to off tommorrow                              0      0       0
# I need a break for today                                 0      0       0
# I need to go at 3pm                                      0      0       0
# I will go at 5pm today                                   0      0       0
# i will go on short break                                 0      0       0
# I am willing to take leave for                           0      0       0
# I am willing to take leave for tomorrow                  0      0       0
# I need a sick leave for today                            0      0       0
# I need a sick leave for                                  0      0       0
# Please show my leaves                                    0      0       0
# When will I get my annual leaves refreshed               0      0       0
# Do I have any sick leave balance?                        0      0       0
# I am planning to take annual leaves from 25th N...       0      0       0
# ...                                                    ...    ...     ...
# I am planning a trip in my vacations                     0      0       0
# how many of my casual leaves be in feb                   0      0       0
# I need to take some rest today                           0      0       0
# I am not going office today                              0      0       0
# I am not feeling well today                              0      0       0
# I want to know my pending leaves                         0      0       0
# do I have remaining sick leaves                          0      0       0
# apply annual leaves from 25th feb to 1st dec             0      0       0
# I have to go somewhere tomorow                           0      0       0
# what is my casual leave renewal date                     0      0       0
# let me know my leave approval authority                  0      0       0
# I will not be joining office today                       0      0       0
# I don’t feel good today                                  0      0       0
# how many pending leaves I have                           0      0       0
# what is my date of annual leave refresh/refreshing       0      0       0
# what is my sick leave balance                            0      0       0
# I want to go to annual leaves from 25th novembe...       0      0       0
# who authorize to my leaves                               0      0       0
# I want to take leave today                               0      0       0
# I don’t think I am well  today                           0      0       0
# who is my leave authority                                0      0       0
# who is my direct reporting with repect  leave            0      0       0
# any sick leave balance left                              0      0       0
# I will be taking leave today                             0      0       0
# I am very sick today                                     0      0       0
# I am not willing to go office today                      0      0       0
# Lets take leave today                                    0      0       0
# I need to take some rest today                           0      0       0
# what is leave incashment policy                          0      0       0
# I am writing to document my absence due to illn...       0      0       0
#
#                                                     balanc  casual  due  go  \
# Text
# I am willing to take leave for today                     0       0    1   0
# I need a sick leave for tomorrow                         0       0    1   0
# Please show my pending leaves                            0       0    1   0
# I will take leave from 4th march to 8th dec              0       0    1   0
# I will not join office from 6th to 9th dec               0       0    1   0
# I am going on annual leaves                              0       0    1   0
# I will go to casual leave for 5th march                  0       0    1   0
# Can you please apply a leave on behave of me.            0       0    1   0
# Can you please request for a sick leave for 8th...       0       0    1   0
# Can you please grant me a casual leave.                  0       0    1   0
# Please show my all leaves.                               0       0    1   0
# Please tell me the balance of casual leave               0       0    1   0
# Please tell me the balance of sick leave                 0       0    1   0
# Please tell me the balance of annual leave               0       0    1   0
# Please initiate me my leave balances                     0       0    1   0
# Please provide me the list of leave balances             0       0    1   0
# Please prompt me the leave balances                      0       0    1   0
# I am going to off tommorrow                              0       0    1   0
# I need a break for today                                 0       0    1   0
# I need to go at 3pm                                      0       0    1   0
# I will go at 5pm today                                   0       0    1   0
# i will go on short break                                 0       0    1   0
# I am willing to take leave for                           0       0    1   0
# I am willing to take leave for tomorrow                  0       0    1   0
# I need a sick leave for today                            0       0    1   0
# I need a sick leave for                                  0       0    1   0
# Please show my leaves                                    0       0    1   0
# When will I get my annual leaves refreshed               0       0    1   0
# Do I have any sick leave balance?                        0       0    1   0
# I am planning to take annual leaves from 25th N...       0       0    1   0
# ...                                                    ...     ...  ...  ..
# I am planning a trip in my vacations                     0       0    1   0
# how many of my casual leaves be in feb                   0       0    1   0
# I need to take some rest today                           0       0    1   0
# I am not going office today                              0       0    1   0
# I am not feeling well today                              0       0    1   0
# I want to know my pending leaves                         0       0    1   0
# do I have remaining sick leaves                          0       0    1   0
# apply annual leaves from 25th feb to 1st dec             0       0    1   0
# I have to go somewhere tomorow                           0       0    1   0
# what is my casual leave renewal date                     0       0    1   0
# let me know my leave approval authority                  0       0    1   0
# I will not be joining office today                       0       0    1   0
# I don’t feel good today                                  0       0    1   0
# how many pending leaves I have                           0       0    1   0
# what is my date of annual leave refresh/refreshing       0       0    1   0
# what is my sick leave balance                            0       0    1   0
# I want to go to annual leaves from 25th novembe...       0       0    1   0
# who authorize to my leaves                               0       0    1   0
# I want to take leave today                               0       0    1   0
# I don’t think I am well  today                           0       0    1   0
# who is my leave authority                                0       0    1   0
# who is my direct reporting with repect  leave            0       0    1   0
# any sick leave balance left                              0       0    1   0
# I will be taking leave today                             0       0    1   0
# I am very sick today                                     0       0    1   0
# I am not willing to go office today                      0       0    1   0
# Lets take leave today                                    0       0    1   0
# I need to take some rest today                           0       0    1   0
# what is leave incashment policy                          0       0    1   0
# I am writing to document my absence due to illn...       0       0    1   0
#
#                                                     join  leav  need  offic  \
# Text
# I am willing to take leave for today                   0     0     0      0
# I need a sick leave for tomorrow                       0     0     0      0
# Please show my pending leaves                          0     0     0      0
# I will take leave from 4th march to 8th dec            0     0     0      0
# I will not join office from 6th to 9th dec             0     0     0      0
# I am going on annual leaves                            0     0     0      0
# I will go to casual leave for 5th march                0     0     0      0
# Can you please apply a leave on behave of me.          0     0     0      0
# Can you please request for a sick leave for 8th...     0     0     0      0
# Can you please grant me a casual leave.                0     0     0      0
# Please show my all leaves.                             0     0     0      0
# Please tell me the balance of casual leave             0     0     0      0
# Please tell me the balance of sick leave               0     0     0      0
# Please tell me the balance of annual leave             0     0     0      0
# Please initiate me my leave balances                   0     0     0      0
# Please provide me the list of leave balances           0     0     0      0
# Please prompt me the leave balances                    0     0     0      0
# I am going to off tommorrow                            0     0     0      0
# I need a break for today                               0     0     0      0
# I need to go at 3pm                                    0     0     0      0
# I will go at 5pm today                                 0     0     0      0
# i will go on short break                               0     0     0      0
# I am willing to take leave for                         0     0     0      0
# I am willing to take leave for tomorrow                0     0     0      0
# I need a sick leave for today                          0     0     0      0
# I need a sick leave for                                0     0     0      0
# Please show my leaves                                  0     0     0      0
# When will I get my annual leaves refreshed             0     0     0      0
# Do I have any sick leave balance?                      0     0     0      0
# I am planning to take annual leaves from 25th N...     0     0     0      0
# ...                                                  ...   ...   ...    ...
# I am planning a trip in my vacations                   0     0     0      0
# how many of my casual leaves be in feb                 0     0     0      0
# I need to take some rest today                         0     0     0      0
# I am not going office today                            0     0     0      0
# I am not feeling well today                            0     0     0      0
# I want to know my pending leaves                       0     0     0      0
# do I have remaining sick leaves                        0     0     0      0
# apply annual leaves from 25th feb to 1st dec           0     0     0      0
# I have to go somewhere tomorow                         0     0     0      0
# what is my casual leave renewal date                   0     0     0      0
# let me know my leave approval authority                0     0     0      0
# I will not be joining office today                     0     0     0      0
# I don’t feel good today                                0     0     0      0
# how many pending leaves I have                         0     0     0      0
# what is my date of annual leave refresh/refreshing     0     0     0      0
# what is my sick leave balance                          0     0     0      0
# I want to go to annual leaves from 25th novembe...     0     0     0      0
# who authorize to my leaves                             0     0     0      0
# I want to take leave today                             0     0     0      0
# I don’t think I am well  today                         0     0     0      0
# who is my leave authority                              0     0     0      0
# who is my direct reporting with repect  leave          0     0     0      0
# any sick leave balance left                            0     0     0      0
# I will be taking leave today                           0     0     0      0
# I am very sick today                                   0     0     0      0
# I am not willing to go office today                    0     0     0      0
# Lets take leave today                                  0     0     0      0
# I need to take some rest today                         0     0     0      0
# what is leave incashment policy                        0     0     0      0
# I am writing to document my absence due to illn...     0     0     0      0
#
#                                                     pleas  request  sick  \
# Text
# I am willing to take leave for today                    0        0     0
# I need a sick leave for tomorrow                        0        0     0
# Please show my pending leaves                           0        0     0
# I will take leave from 4th march to 8th dec             0        0     0
# I will not join office from 6th to 9th dec              0        0     0
# I am going on annual leaves                             0        0     0
# I will go to casual leave for 5th march                 0        0     0
# Can you please apply a leave on behave of me.           0        0     0
# Can you please request for a sick leave for 8th...      0        0     0
# Can you please grant me a casual leave.                 0        0     0
# Please show my all leaves.                              0        0     0
# Please tell me the balance of casual leave              0        0     0
# Please tell me the balance of sick leave                0        0     0
# Please tell me the balance of annual leave              0        0     0
# Please initiate me my leave balances                    0        0     0
# Please provide me the list of leave balances            0        0     0
# Please prompt me the leave balances                     0        0     0
# I am going to off tommorrow                             0        0     0
# I need a break for today                                0        0     0
# I need to go at 3pm                                     0        0     0
# I will go at 5pm today                                  0        0     0
# i will go on short break                                0        0     0
# I am willing to take leave for                          0        0     0
# I am willing to take leave for tomorrow                 0        0     0
# I need a sick leave for today                           0        0     0
# I need a sick leave for                                 0        0     0
# Please show my leaves                                   0        0     0
# When will I get my annual leaves refreshed              0        0     0
# Do I have any sick leave balance?                       0        0     0
# I am planning to take annual leaves from 25th N...      0        0     0
# ...                                                   ...      ...   ...
# I am planning a trip in my vacations                    0        0     0
# how many of my casual leaves be in feb                  0        0     0
# I need to take some rest today                          0        0     0
# I am not going office today                             0        0     0
# I am not feeling well today                             0        0     0
# I want to know my pending leaves                        0        0     0
# do I have remaining sick leaves                         0        0     0
# apply annual leaves from 25th feb to 1st dec            0        0     0
# I have to go somewhere tomorow                          0        0     0
# what is my casual leave renewal date                    0        0     0
# let me know my leave approval authority                 0        0     0
# I will not be joining office today                      0        0     0
# I don’t feel good today                                 0        0     0
# how many pending leaves I have                          0        0     0
# what is my date of annual leave refresh/refreshing      0        0     0
# what is my sick leave balance                           0        0     0
# I want to go to annual leaves from 25th novembe...      0        0     0
# who authorize to my leaves                              0        0     0
# I want to take leave today                              0        0     0
# I don’t think I am well  today                          0        0     0
# who is my leave authority                               0        0     0
# who is my direct reporting with repect  leave           0        0     0
# any sick leave balance left                             0        0     0
# I will be taking leave today                            0        0     0
# I am very sick today                                    0        0     0
# I am not willing to go office today                     0        0     0
# Lets take leave today                                   0        0     0
# I need to take some rest today                          0        0     0
# what is leave incashment policy                         0        0     0
# I am writing to document my absence due to illn...      0        0     0
#
#                                                     take  today  want  work
# Text
# I am willing to take leave for today                   0      0     0     1
# I need a sick leave for tomorrow                       0      0     0     1
# Please show my pending leaves                          0      0     0     1
# I will take leave from 4th march to 8th dec            0      0     0     1
# I will not join office from 6th to 9th dec             0      0     0     1
# I am going on annual leaves                            0      0     0     1
# I will go to casual leave for 5th march                0      0     0     1
# Can you please apply a leave on behave of me.          0      0     0     1
# Can you please request for a sick leave for 8th...     0      0     0     1
# Can you please grant me a casual leave.                0      0     0     1
# Please show my all leaves.                             0      0     0     1
# Please tell me the balance of casual leave             0      0     0     1
# Please tell me the balance of sick leave               0      0     0     1
# Please tell me the balance of annual leave             0      0     0     1
# Please initiate me my leave balances                   0      0     0     1
# Please provide me the list of leave balances           0      0     0     1
# Please prompt me the leave balances                    0      0     0     1
# I am going to off tommorrow                            0      0     0     1
# I need a break for today                               0      0     0     1
# I need to go at 3pm                                    0      0     0     1
# I will go at 5pm today                                 0      0     0     1
# i will go on short break                               0      0     0     1
# I am willing to take leave for                         0      0     0     1
# I am willing to take leave for tomorrow                0      0     0     1
# I need a sick leave for today                          0      0     0     1
# I need a sick leave for                                0      0     0     1
# Please show my leaves                                  0      0     0     1
# When will I get my annual leaves refreshed             0      0     0     1
# Do I have any sick leave balance?                      0      0     0     1
# I am planning to take annual leaves from 25th N...     0      0     0     1
# ...                                                  ...    ...   ...   ...
# I am planning a trip in my vacations                   0      0     0     1
# how many of my casual leaves be in feb                 0      0     0     1
# I need to take some rest today                         0      0     0     1
# I am not going office today                            0      0     0     1
# I am not feeling well today                            0      0     0     1
# I want to know my pending leaves                       0      0     0     1
# do I have remaining sick leaves                        0      0     0     1
# apply annual leaves from 25th feb to 1st dec           0      0     0     1
# I have to go somewhere tomorow                         0      0     0     1
# what is my casual leave renewal date                   0      0     0     1
# let me know my leave approval authority                0      0     0     1
# I will not be joining office today                     0      0     0     1
# I don’t feel good today                                0      0     0     1
# how many pending leaves I have                         0      0     0     1
# what is my date of annual leave refresh/refreshing     0      0     0     1
# what is my sick leave balance                          0      0     0     1
# I want to go to annual leaves from 25th novembe...     0      0     0     1
# who authorize to my leaves                             0      0     0     1
# I want to take leave today                             0      0     0     1
# I don’t think I am well  today                         0      0     0     1
# who is my leave authority                              0      0     0     1
# who is my direct reporting with repect  leave          0      0     0     1
# any sick leave balance left                            0      0     0     1
# I will be taking leave today                           0      0     0     1
# I am very sick today                                   0      0     0     1
# I am not willing to go office today                    0      0     0     1
# Lets take leave today                                  0      0     0     1
# I need to take some rest today                         0      0     0     1
# what is leave incashment policy                        0      0     0     1
# I am writing to document my absence due to illn...     0      0     0     1
#
# [262 rows x 18 columns]

# %%
import nltk
from nltk.tokenize import ToktokTokenizer
x=nltk.FreqDist(ToktokTokenizer().tokenize(newDF))
plt.figure(figsize=(16,5))
x.plot(20)

# %%
import pandas as DataFrame
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.naive_bayes import GaussianNB

classifier = BinaryRelevance(GaussianNB())

# %%
# Out:
# array([[-2.22044605e-16,  9.01082763e-01,  8.68403761e-01, ...,
#          2.55682788e-01,  6.77801662e-01,  1.00000000e+00],
#        [ 9.01082763e-01,  0.00000000e+00,  8.74608279e-01, ...,
#          5.61951604e-01,  6.92992715e-01,  1.00000000e+00],
#        [ 8.68403761e-01,  8.74608279e-01, -2.22044605e-16, ...,
#          1.00000000e+00,  5.91567605e-01,  6.55454679e-01],
#        ...,
#        [ 2.55682788e-01,  5.61951604e-01,  1.00000000e+00, ...,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 6.77801662e-01,  6.92992715e-01,  5.91567605e-01, ...,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  1.00000000e+00,  6.55454679e-01, ...,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00]])

# %%
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import re
from sklearn.manifold import MDS
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dists)

xs, ys = pos[:, 0], pos[:, 1]

cluster_colors = {0: 'red', 1: 'blue'}

cluster_names = {0: 'leave', 1: 'inquiry'}

data = pd.DataFrame({'x': xs, 'y':ys, 'label':collect_top, 'Text': train['Text']}) 

groups = data.groupby('label')

fig, ax = plt.subplots(figsize=(17, 9)) 

ax.margins(0.05) 

for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=8, label=cluster_names[name], color=cluster_colors[name], mec='none')
    ax.set_aspect('auto')
    ax.tick_params(axis='x',which='both',bottom='off',top='off',labelbottom='off')
    ax.tick_params(axis= 'y',which='both',left='off',top='off',labelleft='off')
    
ax.legend(numpoints=1)

for i in range(len(data)):
    ax.text(data.ix[i]['x'], data.ix[i]['y'], data.ix[i]['sentiment'], size=6)  
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-7c4320a8fdd5> in <module>
#       9 cluster_names = {0: 'leave', 1: 'inquiry'}
#      10
# ---> 11 data = pd.DataFrame({'x': xs, 'y':ys, 'label':collect_top, 'Text': train['Text']})
#      12
#      13 groups = data.groupby('label')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    7400             lengths = list(set(raw_lengths))
#    7401             if len(lengths) > 1:
# -> 7402                 raise ValueError('arrays must all be same length')
#    7403
#    7404             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tokenizer = TweetTokenizer()

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2), tokenizer=tokenizer.tokenize)
full_text = list(train['Text'].values) #+ list(test['Phrase'].values)
vectorizer.fit(full_text)
train_vectorized = vectorizer.transform(train['Text'])
#test_vectorized = vectorizer.transform(test['Phrase'])

# %%
print(train_vectorized[1])
# Out:
#   (0, 1120)	0.3338759621471622
#   (0, 956)	0.29173401761897333
#   (0, 953)	0.2560931175220372
#   (0, 750)	0.2994565050820673
#   (0, 749)	0.27812271827507534
#   (0, 607)	0.24266166745332102
#   (0, 594)	0.13902074118908894
#   (0, 524)	0.2881211819102988
#   (0, 508)	0.12977200309150388
#   (0, 431)	0.42127914583516773
#   (0, 406)	0.2103383372851738
#   (0, 111)	0.3543479260581099
#   (0, 90)	0.2132162002110015

# %%
y = train['Text']
y
# Out:
# 0                   I am willing to take leave for today
# 1                       I need a sick leave for tomorrow
# 2                          Please show my pending leaves
# 3            I will take leave from 4th march to 8th dec
# 4             I will not join office from 6th to 9th dec
# 5                            I am going on annual leaves
# 6                I will go to casual leave for 5th march
# 7          Can you please apply a leave on behave of me.
# 8      Can you please request for a sick leave for 8t...
# 9                Can you please grant me a casual leave.
# 10                            Please show my all leaves.
# 11            Please tell me the balance of casual leave
# 12              Please tell me the balance of sick leave
# 13            Please tell me the balance of annual leave
# 14                  Please initiate me my leave balances
# 15          Please provide me the list of leave balances
# 16                   Please prompt me the leave balances
# 17                           I am going to off tommorrow
# 18                              I need a break for today
# 19                                  I need to go at 3pm
# 20                                I will go at 5pm today
# 21                              i will go on short break
# 22                       I am willing to take leave for
# 23               I am willing to take leave for tomorrow
# 24                         I need a sick leave for today
# 25                               I need a sick leave for
# 26                                 Please show my leaves
# 27            When will I get my annual leaves refreshed
# 28                     Do I have any sick leave balance?
# 29     I am planning to take annual leaves from 25th ...
#                              ...
# 232                 I am planning a trip in my vacations
# 233               how many of my casual leaves be in feb
# 234                       I need to take some rest today
# 235                          I am not going office today
# 236                          I am not feeling well today
# 237                     I want to know my pending leaves
# 238                      do I have remaining sick leaves
# 239         apply annual leaves from 25th feb to 1st dec
# 240                       I have to go somewhere tomorow
# 241                 what is my casual leave renewal date
# 242              let me know my leave approval authority
# 243                   I will not be joining office today
# 244                              I don’t feel good today
# 245                       how many pending leaves I have
# 246    what is my date of annual leave refresh/refres...
# 247                        what is my sick leave balance
# 248    I want to go to annual leaves from 25th novemb...
# 249                           who authorize to my leaves
# 250                           I want to take leave today
# 251                       I don’t think I am well  today
# 252                            who is my leave authority
# 253        who is my direct reporting with repect  leave
# 254                         any sick leave balance left
# 255                         I will be taking leave today
# 256                                 I am very sick today
# 257                  I am not willing to go office today
# 258                                Lets take leave today
# 259                       I need to take some rest today
# 260                      what is leave incashment policy
# 261    I am writing to document my absence due to ill...
# Name: Text, Length: 262, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score

# Train, test splits
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, 
                                                    stratify=y, 
                                                    random_state=42)

# Decision trees with depth = 2
clf = DecisionTreeClassifier(max_depth=2, random_state=42)
clf.fit(X_train, y_train)
preds = clf.predict_proba(X_test)
print('Accuracy: {:.5f}'.format(accuracy_score(y_test, 
                                                preds.argmax(axis=1))))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

# %%
logreg = LogisticRegression()
ovr = OneVsRestClassifier(logreg)

# %%
ovr.fit(train_vectorized, y)
# Out:
# C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False),
#           n_jobs=None)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(ovr, train_vectorized, y, scoring='accuracy', n_jobs=-1, cv=2)
print('Cross-validation mean accuracy {0:.2f}%, std {1:.2f}.'.format(np.mean(scores) * 100, np.std(scores) * 100))
# Out:
# C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=2.
#   % (min_groups, self.n_splits)), Warning)
# Cross-validation mean accuracy 51.17%, std 48.83.

# %%
from sklearn.svm import LinearSVC

# %%
svc = LinearSVC(dual=False)
scores = cross_val_score(svc, train_vectorized, y, scoring='accuracy', n_jobs=-1, cv=2)
print('Cross-validation mean accuracy {0:.2f}%, std {1:.2f}.'.format(np.mean(scores) * 100, np.std(scores) * 100))
# Out:
# C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=2.
#   % (min_groups, self.n_splits)), Warning)
# Cross-validation mean accuracy 51.17%, std 48.83.

# %%
ovr.fit(train_vectorized, y);
svc.fit(train_vectorized, y);
# Out:
# C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Conv1D, GRU, CuDNNGRU, CuDNNLSTM, BatchNormalization
from keras.layers import Bidirectional, GlobalMaxPool1D, MaxPooling1D, Add, Flatten
from keras.layers import GlobalAveragePooling1D, GlobalMaxPooling1D, concatenate, SpatialDropout1D
from keras.models import Model, load_model
from keras import initializers, regularizers, constraints, optimizers, layers, callbacks
from keras import backend as K
from keras.engine import InputSpec, Layer
from keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint, TensorBoard, Callback, EarlyStopping

# %%
tk = Tokenizer(lower = True, filters='')
tk.fit_on_texts(full_text)
train_tokenized = tk.texts_to_sequences(train['Text'])
#test_tokenized = tk.texts_to_sequences(test['Phrase'])
max_len = 50
X_train = pad_sequences(train_tokenized, maxlen = max_len)
#X_test = pad_sequences(test_tokenized, maxlen = max_len)

# %%
import gc
from tensorflow.keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer

# %%
embedding_path = open("C:\\Users\\shiza.abid\\Downloads\\glove.6B.50d.txt",encoding="utf8")

# %%
from tqdm import tqdm

# %%
embeddings_index = dict()
for line in tqdm(embedding_path):
                #split up line into an indexed array
    values = line.split()
                #first index is word
    word = values[0]
                #store the rest of the values in the array as a new array
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs #50 dimensions
embedding_path.close()
# Out:
# 0it [00:00, ?it/s]
# 5166it [00:00, 51523.33it/s]
# 10762it [00:00, 52732.50it/s]
# 16360it [00:00, 53626.53it/s]
# 21846it [00:00, 53949.18it/s]
# 27356it [00:00, 54245.59it/s]
# 33026it [00:00, 54916.83it/s]
# 38617it [00:00, 55167.08it/s]
# 44149it [00:00, 55169.21it/s]
# 49740it [00:00, 55336.46it/s]
# 55346it [00:01, 55513.56it/s]
# 60896it [00:01, 55459.20it/s]
# 66342it [00:01, 54128.09it/s]
# 71692it [00:01, 52463.92it/s]
# 77213it [00:01, 53255.33it/s]
# 82519it [00:01, 52914.74it/s]
# 87797it [00:01, 51813.39it/s]
# 93284it [00:01, 52658.07it/s]
# 98572it [00:01, 52682.46it/s]
# 103841it [00:01, 51940.20it/s]
# 109215it [00:02, 52419.86it/s]
# 114685it [00:02, 53045.63it/s]
# 120205it [00:02, 53635.97it/s]
# 125573it [00:02, 52812.99it/s]
# 130861it [00:02, 51698.69it/s]
# 136355it [00:02, 52589.86it/s]
# 141889it [00:02, 53345.59it/s]
# 147339it [00:02, 53644.50it/s]
# 152816it [00:02, 53934.85it/s]
# 158217it [00:02, 53918.98it/s]
# 163613it [00:03, 52316.59it/s]
# 168858it [00:03, 52002.64it/s]
# 174273it [00:03, 52587.90it/s]
# 179541it [00:03, 52104.22it/s]
# 185018it [00:03, 52831.23it/s]
# 190516it [00:03, 53416.50it/s]
# 196056it [00:03, 53959.06it/s]
# 201491it [00:03, 54032.58it/s]
# 206899it [00:03, 52428.89it/s]
# 212156it [00:03, 51959.33it/s]
# 217479it [00:04, 52287.14it/s]
# 222926it [00:04, 52888.14it/s]
# 228406it [00:04, 53402.70it/s]
# 233837it [00:04, 53629.33it/s]
# 239367it [00:04, 54077.49it/s]
# 244779it [00:04, 53965.99it/s]
# 250179it [00:04, 53610.86it/s]
# 255543it [00:04, 52089.98it/s]
# 260764it [00:04, 50640.78it/s]
# 265904it [00:05, 50805.85it/s]
# 271374it [00:05, 51876.55it/s]
# 276576it [00:05, 51574.21it/s]
# 282016it [00:05, 52350.29it/s]
# 287406it [00:05, 52764.45it/s]
# 292881it [00:05, 53288.32it/s]
# 298389it [00:05, 53771.35it/s]
# 303904it [00:05, 54135.22it/s]
# 309402it [00:05, 54339.56it/s]
# 314912it [00:05, 54525.72it/s]
# 320368it [00:06, 52368.51it/s]
# 325625it [00:06, 51991.96it/s]
# 331063it [00:06, 52650.57it/s]
# 336513it [00:06, 53150.61it/s]
# 342019it [00:06, 53665.62it/s]
# 347478it [00:06, 53898.74it/s]
# 352874it [00:06, 51920.68it/s]
# 358296it [00:06, 52548.92it/s]
# 363792it [00:06, 53208.60it/s]
# 369249it [00:06, 53567.05it/s]
# 374679it [00:07, 53747.43it/s]
# 380061it [00:07, 53485.42it/s]
# 385415it [00:07, 52668.27it/s]
# 390799it [00:07, 52972.48it/s]
# 396226it [00:07, 53284.90it/s]
# 400000it [00:07, 53211.33it/s]

# %%
gc.collect()
# Out:
# 1855

# %%
all_embs = np.stack(list(embeddings_index.values()))
emb_mean,emb_std = all_embs.mean(), all_embs.std()

embed_size = all_embs.shape[1]

# %%
max_features = 100000
maxlen = 200

tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(y)

sequences = tokenizer.texts_to_sequences(y)

padsequence = pad_sequences(sequences, maxlen=maxlen)

# %%
len(tokenizer.word_index)
# Out:
# 356

# %%
embed_size = 300
#max_features = 30000
nb_words = len(tokenizer.word_index) +1
        #We are going to set the embedding size to the pretrained dimension as we are replicating it.
        #the size will be Number of Words in Vocab X Embedding Size
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
gc.collect()
# Out:
# 0

# %%
embedding_matrix.shape
# Out:
# (357, 300)

# %%
y[1]
# Out:
# 'I need a sick leave for tomorrow'

# %%
embedding_matrix[1]
# Out:
# array([ 2.42072543e-01,  1.09708563e+00, -7.41304372e-02,  1.59850172e-01,
#         7.35630901e-01,  8.22703936e-01, -2.90602190e-01,  1.89199708e-02,
#        -9.83740351e-01,  2.37158009e-02,  5.82867067e-01, -7.34705966e-01,
#         7.78017382e-01,  1.04316152e+00, -5.50161028e-01,  4.06846739e-02,
#        -1.00423417e+00,  1.09087441e+00,  1.11089670e+00,  1.58543966e-01,
#         4.99848486e-01, -3.07367157e-01, -2.74086514e-01, -1.05034104e-01,
#         1.26760303e+00, -5.34803682e-02,  5.25549132e-01,  4.50268158e-01,
#         4.91099863e-01,  6.24564299e-01, -4.72045458e-01,  1.88603146e-01,
#         1.72865314e-01, -2.21188327e-01,  6.24652870e-01, -4.46361904e-01,
#        -2.75666429e-01,  5.74280756e-01,  5.29978078e-01,  1.74543514e-01,
#        -1.41791492e-01, -5.03886944e-01, -1.25219852e-01, -7.17851889e-01,
#         9.11286951e-01,  4.87028412e-01, -1.10864554e+00,  9.91603644e-01,
#        -3.47935094e-01,  8.74085162e-01, -5.77147092e-01, -7.99093476e-01,
#        -1.26238038e-01, -5.50239395e-01, -5.07406097e-01, -5.99684319e-02,
#         3.07086230e-01,  4.07633962e-01, -9.28957066e-01, -9.10094187e-01,
#        -8.78015148e-01,  4.32364097e-01,  3.16605077e-01, -1.64468824e-01,
#        -3.22683995e-01,  1.17393531e-01,  8.80617682e-01,  1.47015299e+00,
#        -3.13022243e-01, -7.54451802e-01,  7.21641174e-01, -4.64450094e-01,
#         2.67322081e-02,  4.43290910e-01,  3.25790775e-02,  6.31564442e-01,
#         6.74952172e-01, -1.24764409e-01,  8.43384431e-01, -3.30843791e-01,
#        -6.71187123e-01,  2.40149950e-01,  5.50490530e-01,  8.95430729e-01,
#         3.04214479e-01, -6.05038281e-01,  8.90257479e-01,  1.76719139e-01,
#        -6.59956511e-01,  4.96632305e-01,  4.85906264e-01, -1.61466160e-02,
#         1.56532885e-02,  3.82443503e-01,  1.92611763e-01, -3.70919203e-01,
#         1.39309102e-01,  1.43263607e-01,  7.42212577e-01, -8.30504582e-01,
#         3.77014811e-01, -3.13416227e-02, -8.56398977e-02, -3.40547617e-01,
#         5.09702189e-04,  3.94611990e-01, -1.04923584e-01,  2.54788889e-01,
#         7.02533398e-01, -5.34079118e-01,  2.50646590e-01,  7.93426101e-01,
#         1.63939190e+00, -1.27567050e-01,  2.69620003e-02,  5.88633957e-01,
#        -1.70982377e-02, -7.71380424e-01, -5.98462945e-01, -1.48954284e+00,
#         2.30458822e-01,  4.24037675e-01,  3.16073070e-01, -5.38161199e-01,
#         3.10609864e-01,  4.56869457e-01, -1.03455202e+00,  6.86243128e-01,
#        -4.33448370e-01,  1.85241049e-01,  2.05807154e-01, -7.68382218e-01,
#        -8.24967197e-01, -4.62160494e-02,  8.59177869e-01,  1.39499770e-01,
#        -4.12359280e-01, -5.23807697e-02,  1.26040003e+00, -1.42307946e-01,
#         1.27450825e+00, -4.42526765e-01, -1.55193971e+00,  4.08929917e-01,
#         6.33827856e-01,  3.23613882e-01,  1.36639956e-01, -7.07944052e-01,
#        -1.28348817e-02,  3.88096707e-01, -9.03709641e-01, -1.47499292e-02,
#         1.30031793e-01, -9.27355216e-01,  8.90543622e-01,  5.33776861e-01,
#        -1.38540138e+00,  1.04961349e+00,  1.15574662e-01, -1.46615599e+00,
#         5.06971451e-01, -8.10837156e-01, -5.06890336e-01, -2.71371000e-01,
#         7.81412057e-02,  1.18328740e-01,  1.53717999e+00,  1.32537135e+00,
#         1.15957321e+00,  6.32487547e-01, -3.25016516e-01, -1.43626337e+00,
#        -4.78500021e-01, -9.93211877e-01, -5.08601302e-01,  3.85637013e-01,
#         7.08560137e-01, -1.13836596e+00, -1.07139868e+00,  1.02421436e+00,
#        -8.01687157e-03,  2.02906660e-01, -1.43301734e-01, -5.82622861e-01,
#        -1.22197456e+00,  5.89661235e-02,  1.24470761e-01,  4.81584968e-01,
#         2.23173896e-01, -2.02756580e-01, -9.60329851e-02,  1.16158586e+00,
#         2.29286258e-01,  6.16534443e-01,  2.78781352e-01,  5.65559364e-01,
#         4.82083546e-01,  1.64934580e-01,  3.47464788e-01, -4.75142963e-01,
#         5.95453153e-01,  1.23275434e-02,  5.44938694e-01, -2.57357063e-01,
#         1.03669221e-01,  1.14276331e-01, -9.33234988e-02, -3.73649462e-01,
#         3.89453797e-02,  9.77537825e-02, -1.30322408e+00, -1.13838892e+00,
#        -2.16527200e-01,  2.88681904e-01, -2.15507520e-01, -1.20228840e+00,
#         2.58612620e-01, -1.38265734e-02,  7.81973728e-02,  2.40766833e-01,
#         5.63042056e-01, -4.82680042e-01, -9.32037584e-01, -1.18793112e+00,
#        -2.52101103e-01,  8.99916957e-01,  4.55230811e-01,  1.05624860e+00,
#         2.36512615e-01, -5.25826989e-01, -8.46081457e-01, -7.86837146e-01,
#        -3.71328720e-01,  7.58848525e-01, -1.24310090e+00, -5.11747830e-01,
#         5.60298534e-01, -9.00631658e-01, -1.18937184e+00,  3.49272161e-01,
#         3.02916418e-01, -1.24578511e+00, -4.58482420e-02,  9.72107445e-01,
#        -8.17431823e-02,  2.81935391e-01,  1.92850588e-01, -8.72430745e-02,
#        -6.99164472e-01, -1.16207825e+00, -4.42221796e-01,  4.42127894e-01,
#         2.89801103e-01,  4.57492946e-01,  6.16291323e-01,  5.05875252e-01,
#        -1.56548908e+00, -2.57276213e-01,  8.30341972e-02, -5.28871506e-02,
#         5.98576709e-01,  4.90862447e-01, -4.06238176e-01,  3.69162442e-01,
#         1.31910803e+00, -6.43365431e-01,  2.39864095e-01, -4.25578380e-01,
#         1.16282847e+00,  3.27863082e-01,  9.11589212e-01, -2.37075254e-01,
#        -5.14773514e-01, -1.74846457e-01,  1.34248474e-01,  2.81905437e-01,
#        -6.91393205e-01,  1.39170694e+00,  3.34314648e-02,  2.74468201e-01,
#        -1.10603755e-01, -9.74012448e-01,  9.02897768e-01, -2.31867358e-01,
#        -8.65644175e-01,  4.88424729e-01,  4.14702067e-01,  6.96412512e-01,
#        -8.00064911e-01,  2.72872484e-01, -7.84521565e-01, -1.77546323e-01,
#        -9.02000786e-01,  1.65254795e-01, -6.26988644e-02,  8.35558941e-01,
#         5.78383578e-01,  6.76385205e-01, -2.53593092e-01, -1.81505702e-01])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import keras
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense

import gc
from tensorflow.keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.layers import LSTM 
from keras.layers import Embedding, Dense, Dropout

from tqdm import tqdm
import math
import random

from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation
from keras.layers import Bidirectional, GlobalMaxPool1D,Bidirectional
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers

# %%
import tensorflow as tf
len(y)
# Out:
# 262

# %%
vocab_size = 10000

model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation=tf.nn.relu))
model.add(keras.layers.Dense(1, activation=tf.nn.sigmoid))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d_7 ( (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
x_val = y[:65]
partial_x_train = y[65:130]

y_val = y[130:195]
partial_y_train = y[195:260]

# %%
partial_x_train
# Out:
# 65                         What is my sick leave balance
# 66                     What is the current leave balance
# 67                                  I want to rest today
# 68                      I wont be coming to office today
# 69           Can I take sick and annual leaves together?
# 70     I am not able to come office because my grandm...
# 71        Can I take a sick and casual leave this month?
# 72         Am I eligible to take annual leave this year?
# 73         Am I eligible to gain annual leave this year?
# 74           Can I take another casual leave this month?
# 75           Can I take another casual leave this month?
# 76                           When will my leaves expire?
# 77             Will my leaves will retain for next year?
# 78                          When will my leave collapse?
# 79                         How many leave will collapse?
# 80                  How many Leave allowance will I get?
# 81                             When I get my new leaves?
# 82     I wanting to spend my leaves every month, can ...
# 83     I am wishing/Planning/thinking to go on vacati...
# 84     I am wishing/Planning/thinking to go on vacati...
# 85     How much annual leaves will there till next Fe...
# 86                             I need leave due to paper
# 87          I was unable to attend work due to sickness.
# 88     I was unable to report to work due to an acute...
# 89     I've come down with the flu and will not be co...
# 90     I am writing to document my absence due to ill...
# 91      I was unable to attend work on Monday, August...
# 92     Please accept this letter as documentation of ...
# 93     I was unable to attend work on August 1, 2018,...
# 94     I am writing to document my absence on July 15...
#                              ...
# 100    I would like to request a thirty-day leave of ...
# 101    I would like to request a leave of absence for...
# 102    I got up this morning unwell with mild fever, ...
# 103    Because of my ill health, I am not in a positi...
# 104                  I request you to grant casual leave
# 105         I am planning to go out-of-state on vacation
# 106     I request you to kindly grant me leave from work
# 107                           this is a family emergency
# 108           I request unpaid leave during these dates.
# 109    I would like to officially inform you regardin...
# 110                 I am writing to ask for my vacations
# 111                  I request you to grant casual leave
# 112                   kindly give me leave for two days
# 113                  require a lengthy absence from work
# 114    it will not be possible for me to attend offic...
# 115                           I need the break from work
# 116     I have not taken any leave in the past three ...
# 117                     kindly sanction my one day leave
# 118               I will not be able to attend my office
# 119                  I am writing  for leave of two days
# 120                       I will be taking a sick leave
# 121    I have been strongly recommended to have bed r...
# 122       I have to request you for a leave of next week
# 123                          apply a casual leave for me
# 124                            apply a sick leave for me
# 125                       apply a maternity leave for me
# 126                            apply a sick leave for me
# 127                                 apply a leave for me
# 128                          Apply for a maternity leave
# 129                           Kindly grant me sick leave
# Name: Text, Length: 65, dtype: object

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=40,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=2)
# Out:
# Train on 65 samples, validate on 65 samples
# Epoch 1/40
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1316       # Ensure any changes to the graph are reflected in the runtime.
# -> 1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _extend_graph(self)
#    1351     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1352       tf_session.ExtendSession(self._session)
#    1353
#
# InvalidArgumentError: No OpKernel was registered to support Op 'CudnnRNN' used by {{node bidirectional_1/CudnnRNN}}with these attrs: [is_training=true, seed2=0, input_mode="linear_input", T=DT_FLOAT, dropout=0, rnn_mode="gru", direction="unidirectional", seed=87654321]
# Registered devices: [CPU]
# Registered kernels:
#   <no registered kernels>
#
# 	 [[{{node bidirectional_1/CudnnRNN}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-286-3b47c0395482> in <module>
#       4                     batch_size=512,
#       5                     validation_data=(x_val, y_val),
# ----> 6                     verbose=2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2695
#    2696     def __call__(self, inputs):
# -> 2697         if hasattr(get_session(), '_make_callable_from_options'):
#    2698             if py_any(is_sparse(x) for x in self.inputs):
#    2699                 if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     197                 # not already marked as initialized.
#     198                 is_initialized = session.run(
# --> 199                     [tf.is_variable_initialized(v) for v in candidate_vars])
#     200                 uninitialized_vars = []
#     201                 for flag, v in zip(is_initialized, candidate_vars):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# InvalidArgumentError: No OpKernel was registered to support Op 'CudnnRNN' used by node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) with these attrs: [is_training=true, seed2=0, input_mode="linear_input", T=DT_FLOAT, dropout=0, rnn_mode="gru", direction="unidirectional", seed=87654321]
# Registered devices: [CPU]
# Registered kernels:
#   <no registered kernels>
#
# 	 [[node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) ]]
#
# Caused by op 'bidirectional_1/CudnnRNN', defined at:
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\asyncio\base_events.py", line 528, in run_forever
#     self._run_once()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\asyncio\base_events.py", line 1764, in _run_once
#     handle._run()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 1233, in inner
#     self.run()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-191-67225eb9c3bd>", line 1, in <module>
#     model1 = build_model1(lr = 1e-3, lr_d = 1e-10, units = 64, spatial_dr = 0.3, kernel_size1=3, kernel_size2=2, dense_units=32, dr=0.1, conv_size=32)
#   File "<ipython-input-190-de8c8e627aaf>", line 11, in build_model1
#     x_gru = Bidirectional(CuDNNGRU(units, return_sequences = True))(x1)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\wrappers.py", line 427, in __call__
#     return super(Bidirectional, self).__call__(inputs, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 457, in __call__
#     output = self.call(inputs, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\wrappers.py", line 522, in call
#     y = self.forward_layer.call(inputs, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py", line 90, in call
#     output, states = self._process_batch(inputs, initial_state)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py", line 297, in _process_batch
#     is_training=True)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\ops\cudnn_rnn_ops.py", line 1713, in __call__
#     seed=self._seed)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\ops\cudnn_rnn_ops.py", line 1102, in _cudnn_rnn_no_input_c
#     direction, dropout, seed, name)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\ops\cudnn_rnn_ops.py", line 1014, in _cudnn_rnn
#     outputs, output_h, output_c, _ = gen_cudnn_rnn_ops.cudnn_rnn(**args)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\gen_cudnn_rnn_ops.py", line 170, in cudnn_rnn
#     seed2=seed2, is_training=is_training, name=name)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# InvalidArgumentError (see above for traceback): No OpKernel was registered to support Op 'CudnnRNN' used by node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) with these attrs: [is_training=true, seed2=0, input_mode="linear_input", T=DT_FLOAT, dropout=0, rnn_mode="gru", direction="unidirectional", seed=87654321]
# Registered devices: [CPU]
# Registered kernels:
#   <no registered kernels>
#
# 	 [[node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) ]]

# %%
def model():
    
    model = Sequential()
    
    model.add(Embedding(len(tokenizer.word_index)+1,50,input_length=maxlen,weights=[embedding_matrix], trainable=False))
    
    #trainable=False to make sure that the layer obtains encodings from the GloVe vectors 
    #and does not update the weights during training
    
    model.add(LSTM(60, return_sequences=True, recurrent_dropout=0.05))
    
    model.add(Dropout(0.05))
    
    model.add(LSTM(60, recurrent_dropout=0.05))
    
    model.add(Dense(60, activation='relu'))
    
    model.add(Dropout(0.01))
    
    model.add(Dense(2, activation='softmax'))
    
    model.compile(loss='binary_crossentropy', optimizer="rmsprop",metrics=['accuracy'])
    return model

# %%
m= model()

m.fit(padsequence,y,epochs=50, validation_split=0.2,verbose=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-242-39a53c01b57b> in <module>
# ----> 1 m= model()
#       2
#       3 m.fit(padsequence,y,epochs=50, validation_split=0.2,verbose=2)
#
# TypeError: __call__() missing 1 required positional argument: 'inputs'

# %%
def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(embedding_path))

word_index = tk.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.zeros((nb_words + 1, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-208-57cd84fb859e> in <module>
#       1 def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
# ----> 2 embedding_index = dict(get_coefs(*o.strip().split(" ")) for o in open(embedding_path))
#       3
#       4 word_index = tk.word_index
#       5 nb_words = min(max_features, len(word_index))
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
def build_model1(lr=0.0, lr_d=0.0, units=0, spatial_dr=0.0, kernel_size1=3, kernel_size2=2, dense_units=128, dr=0.1, conv_size=32):
    file_path = "best_model.hdf5"
    check_point = ModelCheckpoint(file_path, monitor = "val_loss", verbose = 1,
                                  save_best_only = True, mode = "min")
    early_stop = EarlyStopping(monitor = "val_loss", mode = "min", patience = 3)
    
    inp = Input(shape = (max_len,))
    x = Embedding(357, embed_size, weights = [embedding_matrix], trainable = False)(inp)
    x1 = SpatialDropout1D(spatial_dr)(x)

    x_gru = Bidirectional(CuDNNGRU(units, return_sequences = True))(x1)
    x1 = Conv1D(conv_size, kernel_size=kernel_size1, padding='valid', kernel_initializer='he_uniform')(x_gru)
    avg_pool1_gru = GlobalAveragePooling1D()(x1)
    max_pool1_gru = GlobalMaxPooling1D()(x1)
    
    x3 = Conv1D(conv_size, kernel_size=kernel_size2, padding='valid', kernel_initializer='he_uniform')(x_gru)
    avg_pool3_gru = GlobalAveragePooling1D()(x3)
    max_pool3_gru = GlobalMaxPooling1D()(x3)
    
    x_lstm = Bidirectional(CuDNNLSTM(units, return_sequences = True))(x1)
    x1 = Conv1D(conv_size, kernel_size=kernel_size1, padding='valid', kernel_initializer='he_uniform')(x_lstm)
    avg_pool1_lstm = GlobalAveragePooling1D()(x1)
    max_pool1_lstm = GlobalMaxPooling1D()(x1)
    
    x3 = Conv1D(conv_size, kernel_size=kernel_size2, padding='valid', kernel_initializer='he_uniform')(x_lstm)
    avg_pool3_lstm = GlobalAveragePooling1D()(x3)
    max_pool3_lstm = GlobalMaxPooling1D()(x3)
    
    
    x = concatenate([avg_pool1_gru, max_pool1_gru, avg_pool3_gru, max_pool3_gru,
                    avg_pool1_lstm, max_pool1_lstm, avg_pool3_lstm, max_pool3_lstm])
    x = BatchNormalization()(x)
    x = Dropout(dr)(Dense(dense_units, activation='relu') (x))
    x = BatchNormalization()(x)
    x = Dropout(dr)(Dense(int(dense_units / 2), activation='relu') (x))
    x = Dense(5, activation = "sigmoid")(x)
    model = Model(inputs = inp, outputs = x)
    model.compile(loss = "binary_crossentropy", optimizer = Adam(lr = lr, decay = lr_d), metrics = ["accuracy"])
    history = model.fit(X_train, y_ohe, batch_size = 128, epochs = 20, validation_split=0.1, 
                        verbose = 1, callbacks = [check_point, early_stop])
    model = load_model(file_path)
    return model

# %%
embedding_matrix
# Out:
# array([[ 0.09412522,  0.30161892, -0.53756891, ..., -0.62961921,
#          0.06293754,  0.30135649],
#        [ 0.12680925,  0.25270838, -0.08383186, ..., -0.29292903,
#         -0.47831077, -0.56494609],
#        [ 0.72538433, -0.2256649 ,  0.26550669, ...,  0.93488498,
#         -0.5393117 ,  0.41435752],
#        ...,
#        [ 0.05666389,  0.17015539,  2.00776573, ..., -0.14625773,
#         -0.00238756,  0.33472582],
#        [ 0.54618863,  1.02259656, -0.43982632, ..., -1.75204125,
#          0.00462566, -0.35042299],
#        [-0.00626915, -1.08583779, -1.292799  , ...,  0.22709677,
#          0.15601042, -0.35796153]])

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=False)
y_ohe = ohe.fit_transform(y.values.reshape(-1, 1))

# %%
model1 = build_model1(lr = 1e-3, lr_d = 1e-10, units = 64, spatial_dr = 0.3, kernel_size1=3, kernel_size2=2, dense_units=32, dr=0.1, conv_size=32)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1316       # Ensure any changes to the graph are reflected in the runtime.
# -> 1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _extend_graph(self)
#    1351     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1352       tf_session.ExtendSession(self._session)
#    1353
#
# InvalidArgumentError: No OpKernel was registered to support Op 'CudnnRNN' used by {{node bidirectional_1/CudnnRNN}}with these attrs: [is_training=true, seed2=0, input_mode="linear_input", T=DT_FLOAT, dropout=0, rnn_mode="gru", direction="unidirectional", seed=87654321]
# Registered devices: [CPU]
# Registered kernels:
#   <no registered kernels>
#
# 	 [[{{node bidirectional_1/CudnnRNN}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-212-67225eb9c3bd> in <module>
# ----> 1 model1 = build_model1(lr = 1e-3, lr_d = 1e-10, units = 64, spatial_dr = 0.3, kernel_size1=3, kernel_size2=2, dense_units=32, dr=0.1, conv_size=32)
#
# <ipython-input-209-de8c8e627aaf> in build_model1(lr, lr_d, units, spatial_dr, kernel_size1, kernel_size2, dense_units, dr, conv_size)
#       6
#       7     inp = Input(shape = (max_len,))
# ----> 8     x = Embedding(357, embed_size, weights = [embedding_matrix], trainable = False)(inp)
#       9     x1 = SpatialDropout1D(spatial_dr)(x)
#      10
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     434                 # Load weights that were specified at layer instantiation.
#     435                 if self._initial_weights is not None:
# --> 436                     self.set_weights(self._initial_weights)
#     437
#     438             # Raise exceptions in case the input is not compatible
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\base_layer.py in set_weights(self, weights)
#    1049             return
#    1050         weight_value_tuples = []
# -> 1051         param_values = K.batch_get_value(params)
#    1052         for pv, p, w in zip(param_values, params, weights):
#    1053             if pv.shape != w.shape:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in batch_get_value(ops)
#    2418     """
#    2419     if ops:
# -> 2420         return get_session().run(ops)
#    2421     else:
#    2422         return []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     197                 # not already marked as initialized.
#     198                 is_initialized = session.run(
# --> 199                     [tf.is_variable_initialized(v) for v in candidate_vars])
#     200                 uninitialized_vars = []
#     201                 for flag, v in zip(is_initialized, candidate_vars):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# InvalidArgumentError: No OpKernel was registered to support Op 'CudnnRNN' used by node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) with these attrs: [is_training=true, seed2=0, input_mode="linear_input", T=DT_FLOAT, dropout=0, rnn_mode="gru", direction="unidirectional", seed=87654321]
# Registered devices: [CPU]
# Registered kernels:
#   <no registered kernels>
#
# 	 [[node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) ]]
#
# Caused by op 'bidirectional_1/CudnnRNN', defined at:
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\asyncio\base_events.py", line 528, in run_forever
#     self._run_once()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\asyncio\base_events.py", line 1764, in _run_once
#     handle._run()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 1233, in inner
#     self.run()
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-191-67225eb9c3bd>", line 1, in <module>
#     model1 = build_model1(lr = 1e-3, lr_d = 1e-10, units = 64, spatial_dr = 0.3, kernel_size1=3, kernel_size2=2, dense_units=32, dr=0.1, conv_size=32)
#   File "<ipython-input-190-de8c8e627aaf>", line 11, in build_model1
#     x_gru = Bidirectional(CuDNNGRU(units, return_sequences = True))(x1)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\wrappers.py", line 427, in __call__
#     return super(Bidirectional, self).__call__(inputs, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 457, in __call__
#     output = self.call(inputs, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\wrappers.py", line 522, in call
#     y = self.forward_layer.call(inputs, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py", line 90, in call
#     output, states = self._process_batch(inputs, initial_state)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py", line 297, in _process_batch
#     is_training=True)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\ops\cudnn_rnn_ops.py", line 1713, in __call__
#     seed=self._seed)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\ops\cudnn_rnn_ops.py", line 1102, in _cudnn_rnn_no_input_c
#     direction, dropout, seed, name)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\contrib\cudnn_rnn\python\ops\cudnn_rnn_ops.py", line 1014, in _cudnn_rnn
#     outputs, output_h, output_c, _ = gen_cudnn_rnn_ops.cudnn_rnn(**args)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\gen_cudnn_rnn_ops.py", line 170, in cudnn_rnn
#     seed2=seed2, is_training=is_training, name=name)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# InvalidArgumentError (see above for traceback): No OpKernel was registered to support Op 'CudnnRNN' used by node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) with these attrs: [is_training=true, seed2=0, input_mode="linear_input", T=DT_FLOAT, dropout=0, rnn_mode="gru", direction="unidirectional", seed=87654321]
# Registered devices: [CPU]
# Registered kernels:
#   <no registered kernels>
#
# 	 [[node bidirectional_1/CudnnRNN (defined at C:\Users\shiza.abid\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\layers\cudnn_recurrent.py:297) ]]
